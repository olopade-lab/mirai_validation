# %%
import pandas as pd

# %%
series_metadata_path= "/gpfs/data/huo-lab/Image/annawoodard/maicara/data/interim/mammo_v9/series_metadata.pkl"

# %%
series_metadata = pd.read_pickle(series_metadata_path)

# %%
series_metadata.head()
# Out:
#   Modality      Study DateTime            StudyDescription exam_id  study_id  \
# 0       MG 2012-06-26 10:08:38  MAMMO DIGITAL SCREEN BILAT     NaN  10000462
# 1       MG 2012-06-26 10:08:38  MAMMO DIGITAL SCREEN BILAT     NaN  10000462
# 6       MG 2012-06-26 11:14:54                      Breast     NaN  10000462
# 7       MG 2012-06-26 11:14:54                      Breast     NaN  10000462
# 8       MG 2012-06-26 10:22:40                      Breast     NaN  10000462
#
#        MRN  DNA_available           time_since_exam  study day  study month  \
# 0  3278565           True 3418 days 04:16:24.536007         26            6
# 1  3278565           True 3418 days 04:16:24.536007         26            6
# 6  3278565           True 3418 days 03:10:08.536007         26            6
# 7  3278565           True 3418 days 03:10:08.536007         26            6
# 8  3278565           True 3418 days 04:02:22.536007         26            6
#
#    ...  BluePaletteColorLookupTableData  \
# ...

# %%
metadata = series_metadata[series_metadata['png_path'].notnull()] #drop non-existent png_paths
metadata = metadata[pd.isnull(metadata['filter'])]

# %%
metadata.head()
# Out:
#     Modality      Study DateTime                   StudyDescription  exam_id  \
# 400       MG 2011-05-04 09:43:01  MAM BILAT DIGITAL SCREENING W/CAD  2O03570
# 401       MG 2011-05-04 09:43:01  MAM BILAT DIGITAL SCREENING W/CAD  2O03570
# 408       MG 2011-05-04 09:43:01  MAM BILAT DIGITAL SCREENING W/CAD  2O03570
# 409       MG 2011-05-04 09:43:01  MAM BILAT DIGITAL SCREENING W/CAD  2O03570
# 410       MG 2011-05-04 09:43:01  MAM BILAT DIGITAL SCREENING W/CAD  2O03570
#
#      study_id      MRN  DNA_available           time_since_exam  study day  \
# 400  10930784  1301539          False 3837 days 04:42:01.536007          4
# 401  10930784  1301539          False 3837 days 04:42:01.536007          4
# 408  10930784  1301539          False 3837 days 04:42:01.536007          4
# 409  10930784  1301539          False 3837 days 04:42:01.536007          4
# 410  10930784  1301539          False 3837 days 04:42:01.536007          4
#
# ...

# %%
metadata.columns.to_list()
# Out:
# ['Modality',
#  'Study DateTime',
#  'StudyDescription',
#  'exam_id',
#  'study_id',
#  'MRN',
#  'DNA_available',
#  'time_since_exam',
#  'study day',
#  'study month',
#  'study year',
#  'case',
#  'date_dx',
#  'time_from_exam_to_diagnosis',
#  'years_from_exam_to_diagnosis',
#  'date_of_last_contact',
#  'follow_up_time',
#  'follow_up_years',
#  'time_to_event',
#  'event',
#  'filter',
#  'unique_exam_id',
#  'transfer_complete',
#  'AccessionNumber',
#  'AcquisitionContextSequence',
#  'AcquisitionDate',
#  'AcquisitionDeviceProcessingCode',
#  'AcquisitionDeviceProcessingDescription',
#  'AcquisitionTime',
#  'AnatomicRegionSequence',
#  'AnodeTargetMaterial',
#  'BitsAllocated',
#  'BitsStored',
#  'BodyPartExamined',
#  'BodyPartThickness',
#  'BurnedInAnnotation',
#  'CodeValue',
#  'CollimatorLeftVerticalEdge',
#  'CollimatorLowerHorizontalEdge',
#  'CollimatorRightVerticalEdge',
#  'CollimatorShape',
#  'CollimatorUpperHorizontalEdge',
#  'Columns',
# ...

# %%
# Out:
# Series([], Name: filter, dtype: int64)
